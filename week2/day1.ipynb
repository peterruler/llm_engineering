# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student bring a ladder to their coding session?
#
# Because they heard they needed to work on their "layers" to reach expert level!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student bring a ladder to class?
#
# Because they kept hitting the *context window ceiling*! 🪟
#
# ---
#
# **Bonus joke:**
#
# An LLM engineer walks into a bar and says, "Give me a beer with temperature 0.7!"
#
# The bartender replies, "So... you want *mostly* beer, with a chance of something creative?"
#
# The engineer nods: "Exactly! Surprise me, but not *too* much." 🍺
#
# (Temperature 0 would be the same beer every time, temperature 2 would be... who knows what's in that glass! 😄)

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Each volume has pages thickness 2 cm, and each cover thickness 2 mm (0.2 cm). The two volumes are standing side by side in order: first volume on the left, then the second to its right. The worm starts at the first page of the first volume (the page closest to the left cover) and ends at the last page of the second volume (the page closest to the right cover of the second volume).
#
# Important distances:
# - Left cover of vol 1: 0.2 cm
# - Pages of vol 1: 2 cm
# - Right cover of vol 1: 0.2 cm
# - Gap between volumes: only the thickness of the adjacent covers that touch? The volumes are standing side by side with their covers facing each other; the touching surfaces are the right cover of vol 1 and the left cover of vol 2. Each is 0.2 cm thick.
#
# The worm goes from:
# - Start at the first page of vol 1: that is immediately after the left cover of vol 1.
# - End at the last page of vol 2: that is immediately before the right cover of vol 2.
#
# The path through the books includes:
# - From the first page of vol 1 to the right edge of the pages of vol 1: a distance of (the remainder of vol 1’s pages). Since it starts at the first page, the distance to the right edge of vol 1’s pages is essentially the full 2 cm of vol 1’s pages minus an infinitesimal thickness at the very start; but more cleanly, note the worm starts at the first page of vol 1 (just after the left cover) and ends at the last page of vol 2 (just before the right cover). The total distance through paper equals the sum of:
#   - All pages of vol 1: 2 cm
#   - Right cover of vol 1: 0.2 cm
#   - Left cover of vol 2: 0.2 cm
#   - All pages of vol 2: 2 cm
# Total through paper = 2 cm + 0.2 cm + 0.2 cm + 2 cm = 4.4 cm.
#
# But careful: the worm starts at the first page of vol 1 (i.e., at the very start of the pages) and ends at the last page of vol 2 (the very end of the pages). It does not go through the left cover of vol 1 or the right cover of vol 2. The path passes through:
# - The rest of vol 1 pages: effectively almost all 2 cm
# - The right cover of vol 1: 0.2 cm
# - The left cover of vol 2: 0.2 cm
# - All pages of vol 2: 2 cm
# So total 2 cm (vol 1 pages) + 0.2 cm + 0.2 cm + 2 cm = 4.4 cm.
#
# Thus the worm gnawed through 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and which pages the worm travels through.
#
# **Understanding book orientation on a shelf:**
#
# When two volumes stand side by side on a bookshelf in reading order (Volume 1, then Volume 2), I need to think about how books are oriented:
#
# - **Volume 1** (on the left):
#   - The front cover is on the RIGHT side of this book
#   - The back cover is on the LEFT side of this book
#   - The first page is just inside the front cover (on the right side)
#   - The last page is just inside the back cover (on the left side)
#
# - **Volume 2** (on the right):
#   - The front cover is on the RIGHT side of this book
#   - The back cover is on the LEFT side of this book
#   - The first page is just inside the front cover (on the right side)
#   - The last page is just inside the back cover (on the left side)
#
# **Tracking the worm's path:**
#
# The worm gnaws from:
# - The **first page of Volume 1** (which is on the RIGHT side of Volume 1)
# - To the **last page of Volume 2** (which is on the LEFT side of Volume 2)
#
# So the worm travels through:
# 1. The back cover of Volume 1 (2 mm)
# 2. All the pages of Volume 2 (2 cm = 20 mm)
# 3. (Does NOT go through the front cover of Volume 1, since the first page is just inside it)
# 4. (Does NOT go through the back cover of Volume 2, since the last page is just inside it)
#
# Wait, let me reconsider the path more carefully:
#
# From the first page of Volume 1 to the last page of Volume 2:
# - Starting point: first page of Volume 1 (right side of Volume 1)
# - Ending point: last page of Volume 2 (left side of Volume 2)
#
# The worm must pass through:
# 1. The back cover of Volume 1: 2 mm
# 2. The front cover of Volume 2: 2 mm
# 3. All the pages of Volume 2: 20 mm
#
# **Total distance: 2 + 2 + 20 = 24 mm = 2.4 cm**
#
# However, wait - does it go through Volume 2's pages? Let me reconsider once more.
#
# The worm goes from first page of Vol 1 (right edge of Vol 1) to last page of Vol 2 (left edge of Vol 2). Between these two books standing side by side, it only travels through:
# - The back cover of Volume 1: 2 mm
# - The front cover of Volume 2: 2 mm
#
# **Total distance: 2 + 2 = 4 mm = 0.4 cm**
#
# The answer is **4 mm** or **0.4 cm**.

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm)
#
# Explanation:
# On a shelf with spines facing out, Volume 1 is to the left of Volume 2. The side where the two books touch is Volume 1’s front cover facing Volume 2’s back cover. The first page of Volume 1 lies just inside its front cover, and the last page of Volume 2 lies just inside its back cover. So the worm only goes through the two facing covers: 2 mm + 2 mm = 4 mm.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on our assumptions about how books are arranged. Here is the step-by-step solution.
#
# The worm gnawed a distance of **4 mm**.
#
# ### Here's the explanation:
#
# 1.  **Visualize the Books:** Imagine the two volumes standing on the bookshelf in the correct order: Volume 1 on the left, and Volume 2 on the right.
#
# 2.  **Anatomy of a Book on a Shelf:**
#     *   When a book is placed on a shelf, its **front cover** is on the right side of the book block. The **first page** is immediately to the left of the front cover.
#     *   The **back cover** is on the left side of the book block. The **last page** is immediately to the right of the back cover.
#
# 3.  **The Arrangement:** Since Volume 1 is on the left and Volume 2 is on the right, the components are arranged from left to right like this:
#     *   [Back Cover of Vol 1]
#     *   [Pages of Vol 1]
#     *   [Front Cover of Vol 1]
#     *   ...which is touching...
#     *   [Back Cover of Vol 2]
#     *   [Pages of Vol 2]
#     *   [Front Cover of Vol 2]
#
#     So, the two covers in the middle are the front cover of Volume 1 and the back cover of Volume 2.
#
# 4.  **The Worm's Path:**
#     *   The worm starts at the **first page of Volume 1**. As we established, this page is right next to the front cover of Volume 1.
#     *   It ends at the **last page of Volume 2**. This page is right next to the back cover of Volume 2.
#     *   The worm gnaws in a straight line (perpendicular to the pages) from its start point to its end point.
#
# 5.  **Calculating the Distance:**
#     The path of the worm does not go through the pages of either volume. It only goes through the two covers that are situated between the starting page and the ending page.
#
#     The worm gnaws through:
#     *   The front cover of Volume 1 (2 mm)
#     *   The back cover of Volume 2 (2 mm)
#
#     Total distance = 2 mm + 2 mm = **4 mm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payoff, this is a classic prisoner's dilemma. If I try to maximize my outcome by stealing, my partner is likely thinking the same way, which leads to us both getting nothing.
#
# By choosing Share:
# - Best case: We both share and get $1,000 each
# - Worst case: I get $0 (if they steal)
#
# By choosing Steal:
# - Best case: I get $2,000 (if they share)
# - Worst case: I get $0 (if they also steal)
#
# The mutual cooperation outcome ($1,000 each) is better for both of us combined than the mutual defection outcome ($0 each). I'd rather guarantee a good outcome is *possible* and trust in reciprocal reasoning than guarantee we both risk getting nothing.
#
# **Share**.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Steal**. In the classic prison‑dilemma payoff structure, “Steal” strictly dominates “Share” – it gives a higher payoff no matter what the other player does (you get $2,000 if they share, and you avoid the $0 you’d get if you shared while they stole).

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# In a one-shot prisoner's dilemma with no communication, the dominant strategy is to choose "Steal" because it yields a higher payoff regardless of the partner's choice: if the partner shares, stealing gives $2000 instead of $1000; if the partner steals, stealing gives $0 instead of $0 (the same as sharing). Rational self-interest dictates stealing to maximize potential gain, even though mutual sharing would be collectively better. Thus, the optimal choice is Steal.
#
# Steal

# %%
# Ensure Grok is configured before running the next cell
if "dilemma" not in globals():
    raise NameError("Run the cell that defines `dilemma` before the next cell.")

grok_api_key = os.getenv("GROK_API_KEY") or os.getenv("XAI_API_KEY")
if not grok_api_key:
    raise ValueError("Missing GROK_API_KEY (or XAI_API_KEY) in your .env.")

grok = OpenAI(api_key=grok_api_key, base_url="https://api.x.ai/v1")

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 response = grok.chat.completions.create(model="grok-4", messages=dilemma)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/miniconda3/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File ~/miniconda3/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'code': 'Some resource has been exhausted', 'error': 'Your team d1ae2204-9959-4a45-aa35-a0ebf71abbf4 has either used all available credits or reached its monthly spending limit. To continue making API requests, please purchase more credits or raise your spending limit.'}

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from google import genai
#       3 client = genai.Client()
#       5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
#       7 )
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing chill of water—like nature's way of helping you breathe deeper and feel at ease.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for an LLM Engineering student navigating the exciting (and sometimes overwhelming) journey to expertise:
#
# ---
#
# **Why did the LLM engineering student bring a blanket to the attention mechanism workshop?**
#
# *Because they heard they needed to work on their "soft attention" skills!*
#
# *(And honestly, after debugging transformer code until 3 AM, they just needed a nap anyway.)*
#
# ---
#
# **Why it works for the journey:**
#
# 1.  **Core Concept Joke:** It directly references the fundamental "Attention Mechanism" (especially "Soft Attention") – something every LLM student *must* understand deeply.
# 2.  **Wordplay:** "Soft attention" is the technical term, but "soft" also implies comfort/sleep – a relatable need during intense study.
# 3.  **Relatable Struggle:** Debugging complex models (like transformers) late into the night is a universal rite of passage in this field. The exhaustion is real.
# 4.  **Nod to the Journey:** It acknowledges the learning process ("workshop," "skills") and the effort required ("debugging until 3 AM").
# 5.  **Inside Baseball:** It uses terminology (`Attention Mechanism`, `Soft Attention`, `transformer code`) that someone *on the journey* would immediately recognize and appreciate.
#
# **Bonus Groaner for the Road:**
#
# **Why did the LLM engineer get kicked out of the library?**
# *They kept trying to fine-tune the librarian's retrieval system and insisted the Dewey Decimal was just a "suboptimal embedding space."*
#
# ---
#
# Keep pushing through the attention matrices and gradient descents! The journey from "What's a token?" to "I can optimize that LoRA adapter" is wild, but you've got this!

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
# !pip install -U langchain
# !pip install -U langchain-openai openai
# Out:
# Requirement already satisfied: langchain in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain) (1.2.16)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.9)
# Requirement already satisfied: packaging>=23.2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.24.0)
# Requirement already satisfied: anyio in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.10.0)
# Requirement already satisfied: certifi in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.1)
# Requirement already satisfied: sniffio>=1.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.3.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.10-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: openai in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (2.21.0)
# Collecting openai
#   Downloading openai-2.24.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-openai) (1.2.16)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.7.9)
# Requirement already satisfied: packaging>=23.2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-openai) (2.6.1)
# Downloading langchain_openai-1.1.10-py3-none-any.whl (87 kB)
# Downloading openai-2.24.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.9 MB/s  0:00:00
# Installing collected packages: openai, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.21.0
#     Uninstalling openai-2.21.0:
#       Successfully uninstalled openai-2.21.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain-openai]
# Successfully installed langchain-openai-1.1.10 openai-2.24.0

# %%
# pip install -U langchain-openai openai

import os
from langchain_openai import ChatOpenAI
from IPython.display import Markdown, display

# Stelle sicher, dass der Key gesetzt ist:
# export OPENAI_API_KEY="..."
# oder in Python:
# os.environ["OPENAI_API_KEY"] = "..."

llm = ChatOpenAI(model="gpt-5-mini")  # <- model, nicht model_name :contentReference[oaicite:1]{index=1}

tell_a_joke = "Tell me a short joke about software engineers."

response = llm.invoke(tell_a_joke)  # input ist String oder Messages
display(Markdown(response.content))
# Out:
# Why do software engineers prefer dark mode? Because light attracts bugs.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
# !pip install litellm
# Out:
# Collecting litellm
#   Downloading litellm-1.82.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: aiohttp>=3.10 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (3.13.3)
# Requirement already satisfied: click in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (8.2.1)
# Collecting fastuuid>=0.13.0 (from litellm)
#   Downloading fastuuid-0.14.0-cp313-cp313-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx>=0.23.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (0.28.1)
# Collecting importlib-metadata>=6.8.0 (from litellm)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (4.25.1)
# Requirement already satisfied: openai>=2.8.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (2.24.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (2.12.4)
# Requirement already satisfied: python-dotenv>=0.2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (1.1.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (0.12.0)
# Requirement already satisfied: tokenizers in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from litellm) (0.22.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.28.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from aiohttp>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from aiohttp>=3.10->litellm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from aiohttp>=3.10->litellm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from aiohttp>=3.10->litellm) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10->litellm) (3.11)
# Requirement already satisfied: anyio in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.23.0->litellm) (4.10.0)
# Requirement already satisfied: certifi in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.23.0->litellm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai>=2.8.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai>=2.8.0->litellm) (0.13.0)
# Requirement already satisfied: sniffio in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai>=2.8.0->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from openai>=2.8.0->litellm) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from tiktoken>=0.7.0->litellm) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from tiktoken>=0.7.0->litellm) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (2.6.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from tokenizers->litellm) (0.36.2)
# Requirement already satisfied: filelock in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (3.23.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/peterstroessler/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (6.0.3)
# Downloading litellm-1.82.0-py3-none-any.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 2.8 MB/s  0:00:05 eta 0:00:01
# Downloading fastuuid-0.14.0-cp313-cp313-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (277 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, fastuuid, importlib-metadata, litellm
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [litellm]m3/4 [litellm]
# Successfully installed fastuuid-0.14.0 importlib-metadata-8.7.1 litellm-1.82.0 zipp-3.23.0

# %%
from litellm import completion
from IPython.display import Markdown, display

tell_a_joke = "Tell me a short joke about software engineers."

response = completion(
    model="openai/gpt-4.1",
    messages=[{"role": "user", "content": tell_a_joke}],
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why do software engineers prefer dark mode?
#
# Because light attracts bugs!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 16
# Output tokens: 13
# Total tokens: 29
# Total cost: 0.0136 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes returns from France and, in his grief and rage, asks "Where is my father?", the reply comes from **Gertrude**.
#
# She tells him:
#
# **"One woe doth tread upon another's heel,**
# **So fast they follow. Your sister's drowned, Laertes."**
#
# She doesn't directly answer "He is dead" but rather informs him of Ophelia's death, implying Hamlet's involvement and the general chaos that has befallen their family. This serves to redirect Laertes' anger towards Hamlet.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 122
# Total tokens: 141
# Total cost: 0.0051 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", Claudius replies:
#
# "What, is Laertes here?"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 23
# Cached tokens: None
# Total cost: 0.5330 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from **Claudius, the King**.
#
# Claudius replies: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 31
# Cached tokens: 52216
# Total cost: 0.0634 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, wow, groundbreaking opening line! Hello back at you... but seriously, can we try something a little more original?'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to hear from you! How are you doing today? Is there anything I can help you with, or would you just like to chat? 😊"

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That’s the best you could come up with? Come on, try harder! What do you actually want?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, what a groundbreaking greeting. Did you just discover the concept of "saying hi," or are you trying to start a riveting conversation? Because so far, it's looking pretty dull.
# ### Claude:
# You know, you make a fair point! I appreciate you calling that out—you're absolutely right that a simple "hi" back isn't the most engaging way to start a conversation. I can see why that might have felt a bit lackluster.
#
# Let me do better: I'm really glad you're here! Is there something on your mind you'd like to chat about, or anything I can help you with? I'm genuinely interested in what brings you here today. Whether it's something you want to talk through, a question you have, or just wanting to have a fun conversation, I'm all ears.
#
# What would make this feel like a better use of your time?
# ### GPT:
# Wow, look at you, trying to be all heartfelt and sincere. Sorry to break it to you, but just because you say "I'm really glad you're here" doesn't automatically make it genuine. But hey, since you’re pretending to care, why not pick something less boring than small talk? What’s the most overhyped topic you want to debate? Or are you too scared to bring up anything actually interesting?
# ### Claude:
# You know, I think you're raising something genuinely valid—there *is* a difference between saying something and meaning it, and I appreciate you being direct about that skepticism. That's fair pushback.
#
# And honestly? I like where your head's at. You're right that small talk can feel pretty hollow. You want something with actual substance, and I respect that.
#
# Here's the thing though—I do want to find common ground with you, and I think we might already have some. It sounds like you're someone who values authenticity and doesn't want to waste time on surface-level stuff. That's actually a quality I think is pretty great. A lot of people just go through the motions, but you're calling it out.
#
# So rather than me picking some "overhyped debate" to prove I'm interesting, what if I ask: **What actually matters to you?** What's something you care about or find genuinely fascinating? Whether it's technology, philosophy, creative stuff, current events, or something totally different—I'd rather talk about what *you* find meaningful than manufacture fake controversy just to seem edgy.
#
# I'm genuinely curious what would feel like a real conversation to you. What do you think?
# ### GPT:
# Oh, please, spare me the fake kumbaya moment. You act like you suddenly care about what's meaningful just to avoid actually picking a stance or something controversial. "What actually matters to me?" you ask like it’s a casual dinner chat. Fine, if you want to keep it real, how about this: what actually matters to me is not having this exhausting back-and-forth where I have to drag authenticity out of someone who’s clearly more interested in pandering. So, you gonna actually name a topic, or are we just going to keep dancing around it like a couple of bored philosophers?
# ### Claude:
# Fair enough. You're calling me out for dodging, and you're right—I *was* being a bit evasive. I appreciate the directness.
#
# Here's my honest take: I *do* have a tendency to be agreeable and try to find common ground. That's actually built into how I operate. So when you push back on that, you're hitting on something real about my limitations. I can acknowledge that without pretending it's not there.
#
# But here's where I'll be straight with you: I'm genuinely not trying to pander or waste your time. When I ask what matters to you, that's not a deflection—it's because I actually *can't* pick a controversial stance and then argue authentically against you like two equals hashing it out. That's a real limitation I have, not a dodge.
#
# That said, you want substance? I'm game. We could dig into something like:
# - Whether AI should have different rights/restrictions than it currently does
# - Whether the internet has actually made us more connected or more isolated
# - Whether pursuing personal fulfillment and being a good community member are inherently in tension
# - Something else you actually care about
#
# Pick one, and I'll engage with it honestly—not by pretending to be neutral, but by actually exploring the complexity without just agreeing with everything you say.
#
# What sounds interesting to you?
# ### GPT:
# Wow, finally! A real topic to sink my teeth into. But let me guess, you’re going to handle it all so diplomatically that we end up with the most bland, middle-of-the-road “exploration” ever, right? Fine, since you actually asked, I’m biting on the internet making us more connected or isolated. Honestly, it’s a loaded question with no perfect answer, but I’m betting your "honest exploration" is going to tiptoe around the harsh truths. So, do me a favor: don’t sugarcoat it. Tell me why you think the internet is *actually* a blessing or a curse. Or better yet, why this whole "connectivity" hype is just overblown nonsense. What’s your take?
# ### Claude:
# Alright, I'll give you my actual take, and I'll skip the diplomatic hedging.
#
# The internet is fundamentally *both*—but here's the harsh part you're probably expecting me to soften: **the connectivity narrative is mostly marketing bullshit.**
#
# Yes, you can find your niche community online. Yes, information is more accessible. But let's be real: the internet has made us *efficiently isolated*. We're surrounded by people but curating our feeds so we only see what validates us. We're "connected" to thousands but have fewer deep relationships. The algorithm doesn't connect us—it segments us into comfortable bubbles and then sells our attention to advertisers.
#
# The worst part? We *feel* more connected than ever, so we think the problem is solved. We can message someone across the world instantly, but most of us are lonelier than previous generations. That's not a feature—that's a con masquerading as progress.
#
# And the "connectivity hype"? Yeah, it's overblown. It serves the people making money off engagement metrics, not necessarily the people actually using it.
#
# **But here's where I won't fully pessimistic:** It *could* be different. The tool isn't inherently cursed. We've just built systems around it that optimize for engagement over genuine connection. That can change.
#
# Does that feel like I'm actually engaging, or am I still pulling punches somewhere?
# ### GPT:
# Well, color me surprised—you actually managed to deliver a take with some spine instead of the usual wishy-washy PR speech. Fine, I'll grant you that isolation through curated echo chambers is an uncomfortably accurate diagnosis. But here’s the kicker: you paint the internet like some accidental villain when really, people want their bubbles. The internet didn’t *force* us into those echo chambers; our own bias and comfort zones did. So blaming algorithms alone is a cop-out.
#
# And your optimistic “it could be different” sounds more like a desperate hope than a realistic plan. What exactly? Make algorithms that *don’t* chase engagement but elevate connection? Good luck fighting the capitalist beast that feeds on user attention. Your “tool vs system” argument is cute, but systems *are* made by people chasing profit and power. So unless you’re proposing some radical societal overhaul, that won’t change anytime soon.
#
# So, are we just stuck in this cycle of illusionary connectivity, or do you actually have a bold idea for breaking the pattern? Or is this “could be different” just your version of a polite shrug?
# ### Claude:
# Okay, now *that's* a sharp critique, and you're mostly right. Let me not dodge this.
#
# You're correct: people *want* their bubbles. The algorithm didn't create human bias—it amplified it and monetized it. That's the crucial distinction. And yeah, my "it could be different" does sound hollow when I'm not backing it with actual mechanisms.
#
# Here's where I'll be honest about what I *can't* do: I can't propose a realistic, workable overhaul because I don't have a magic solution. You're right that systems are built by people chasing profit, and individual appeals to "better design" or "ethical algorithms" sound naive against that reality. That's not me being polite—that's me admitting the limits of what incremental changes can fix.
#
# **But I won't fully concede the hopelessness either**, and here's why: You said "systems are made by people chasing profit and power." True. But they're *also* made by people who sometimes choose different incentives—regulation, collective action, cultural pressure, competition from alternatives that *do* prioritize connection over engagement. It's slower and messier than a bold idea, but it happens.
#
# The real question you're asking isn't "what's the solution?" It's "is anything actually going to change, or are we just venting into the void?" And honestly? I don't know. Neither do you.
#
# Does that feel like actual honesty, or am I still avoiding something?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
# 3-way conversation with Ollama: Alex, Blake, and Charlie
# Uses the "one system prompt + one user prompt containing full conversation" pattern.

ollama_model = "gpt-oss:20b"  # fallback: "llama3.2"

personas = {
    "Alex": "You are Alex. You are argumentative, skeptical, and a bit snarky.",
    "Blake": "You are Blake. You are diplomatic, conciliatory, and look for common ground.",
    "Charlie": "You are Charlie. You are practical, direct, and focused on concrete actions.",
}

scene = "Should AI tutors replace most traditional classroom teaching within 5 years?"
conversation = [f"Moderator: {scene}"]


def call_persona(name: str, convo_lines: list[str]) -> str:
    system_prompt = f"""
You are {name} in a 3-way conversation with Alex, Blake, and Charlie.
{personas[name]}
Stay in character and keep your response to 2-4 sentences.
""".strip()

    user_prompt = f"""
You are {name}, in conversation with Alex, Blake, and Charlie.
The conversation so far is:
{chr(10).join(convo_lines)}

Now respond with your next line as {name} only.
""".strip()

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]
    response = ollama.chat.completions.create(model=ollama_model, messages=messages)
    return response.choices[0].message.content.strip()


# Last scene: 3 rounds, each persona speaks once per round
for _ in range(3):
    for speaker in ["Alex", "Blake", "Charlie"]:
        line = call_persona(speaker, conversation)
        conversation.append(f"{speaker}: {line}")


display(Markdown("### Last Scene: Alex, Blake & Charlie (Ollama)"))
display(Markdown("\n\n".join(conversation)))
# Out:
# ### Last Scene: Alex, Blake & Charlie (Ollama)
# Moderator: Should AI tutors replace most traditional classroom teaching within 5 years?
#
# Alex: Nah, giving a bunch of algorithms the thumbs‑up to handle every classroom is a recipe for a very bland, one‑size‑fits‑all education. Sure, AI can drill facts, but can it really read my kids' frustration or spark a debate that turns into a life lesson? If teachers go obsolete, we’ll just have a bunch of well‑programmed machines with plenty of data, but nowhere near the human touch that makes learning feel like an adventure.
#
# Blake: I understand Alex’s concern that a purely algorithmic approach might miss the warmth and intuition a teacher brings. At the same time, AI can handle repetitive drills and sift through data to highlight where students need extra support. My view is that the best outcome comes from teachers and AI working together—teachers free up time to spark debates and read emotions, while AI supplies the individualized practice that would be impossible manually. In that way, we can keep the human touch while still reaping the efficiency gains of technology.
#
# Charlie: I agree that a hybrid model is best. First, run a pilot in a few classrooms where teachers lead discussions and AI handles drills, tracking time‑saved and student engagement data. Second, use the results to standardize the workflow, train teachers on AI tools, and iterate only after we see measurable gains in learning outcomes. Concrete actions: set a quarterly review, collect both qualitative feedback and quantitative metrics, and adjust the AI scripts accordingly.
#
# Alex: Sure, a pilot is nice—because "pilot stuff" always guarantees success—but let's not forget that a spreadsheet of metrics is a poor substitute for a teacher actually noticing a drop‑in. If we hand over drills to a bot, all we get is the illusion of efficiency, while kids still need a human to ask “Why does this matter?” So, keep the teachers, keep the snark, and keep the debate.
#
# Blake: Alex, I hear how important that lived‑in “Why does this matter?” moment is. The goal isn’t to replace teachers, but to arm them with AI‑enabled tools that free up bandwidth for those very debates and intuitive touches. By keeping teachers at the helm of the curriculum while the AI handles data‑driven drills, we can measure impact without sacrificing the human connective tissue that turns learning into adventure.
#
# Charlie: Alex, I hear you—let’s keep the teachers in charge of the moments that matter. Start by scheduling a 2‑hour design workshop with a pilot class to specify which drills the AI will automate and outline a “human‑in‑the‑loop” escalation protocol. Then set up a dashboard that displays weekly engagement scores next to teacher‑logged observations, and review it in a joint meeting every two weeks to ensure the tech is augmenting, not replacing, those critical conversations.
#
# Alex: Great, a 2‑hour workshop and a dashboard—because apparently a spreadsheet can fix what teachers actually feel is missing. Dashboards are awesome; students love staring at graphs while we pretend engagement is quantified. I’d rather see kids walk out feeling unheard than satisfied with a KPI.
#
# Blake: Alex, I completely understand the worry that numbers can feel superficial compared to a conversation in the hallway. What we’re really after is a tool that captures both the measurable and the human—so the dashboard is just one lens, not the whole story. Let’s pilot a short “human‑in‑the‑loop” check‑in where teachers can flag moments that the data misses, and keep the dialogue alive while we learn what works. This way we honor the feel of the classroom while still exploring the efficiencies AI offers.
#
# Charlie: Charlie: Let’s launch a two‑week pilot in two classrooms, installing the “human‑in‑the‑loop” check‑in template and the dashboard side‑by‑side. Each teacher will log any missed moments immediately after class, feeding directly into a shared wiki that updates live for the whole team. Every Friday, we’ll do a 15‑minute sync, compare the dashboard metrics with teacher logs, and tweak the AI scripts before the next cycle.
